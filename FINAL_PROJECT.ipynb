# %% [markdown]
# <a href="https://colab.research.google.com/github/sivacivil12345/Mini-project-dashboard/blob/main/FINAL_PROJECT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Transportation Public Finance Statistics**

# %% [markdown]
# ## **Objective(Problem Statement):**
# The primary objective of this dataset is to analyze and compare transportation-related public finance statistics across U.S. states over multiple years.
# To evaluate and compare transportation finance performance across states by analyzing transportation revenues, expenditures, funding sources, and per-capita spending trends, enabling data-driven transportation planning and public policy decisions.

# %% [markdown]
# ## **Outcome:**
#
# 1.   Transprotation funding analysis
# 2.   state level financial comparison
# 3.   Year-over-year trend analysis
# 4.   inflation - adjusted financial trends
# 5.   Per-capita funding analysis
# 6.   budget planning

# %% [markdown]
# # **Domain:**
# ### Transportation

# %% [markdown]
# #**Dataset Information:**
#
# **Source:** Government portal / Data.gov /  Data Portal link-https://catalog.data.gov/dataset/state-level-transportation-public-finance-statistics-tpfs
#
# **Year / Timeline:** Data updated on Feb 6,2026
#
# **Dataset Column/features Description:**
#
# * **Cash_flow** -Indicates whether the record represents Revenue (money received) or Expenditure (money spent).
#
# * **Own_supporting** - Transportation activities are financially self-supporting or supported by other government funds.
#
# * **User_other** - Identifies whether revenue comes from users (fees, tolls, fares) or other sources (taxes, grants, transfers).
#
# * **Trust_fund** - Whether the transaction is associated with a Trust Fund or Non-Trust Fund.
#
# * **Govt_level** - Level of government responsible for the transaction (State, Local, or State and Local combined).
#
# * **Description**- Detailed explanation of the revenue or expenditure category.
#
#
# * **State** - Name of the U.S. state.
#
# * **Year** - Reporting year of the record.
#
# * **Value** - Original amount reported for the category
# * **Mode** - Transportation mode associated with the record (e.g., highways, transit, aviation, rail).
#
#
# * **Deflator** - Inflation adjustment factor
#
# * **Chained** - Inflation-adjusted value using the deflator.
#
# * **Population** - Population of the state in the given year.
#
# * **Value per population** - Per-capita value calculated as: Value ÷ Population.
# * **Chained per population** - Inflation-adjusted per-capita value calculated as: Chained Value ÷ Population.

# %% [markdown]
# # Stages for DA Project

# %% [markdown]
# ## Stage 1 – Problem Definition and Dataset Selection
#
#
# **NOTE : THINGS TO BE COMPLETED**
#
# * Define the business problem and expected outcome
#
# * Choose dataset and explain its source, size, and features
#
# * Import libraries, load dataset
#
# * Dataset description (rows, columns, features)
#
# * Initial EDA (head, info, describe, shape, null checks, duplicate check)

# %% [markdown]
# # **Inital EDA**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df=pd.read_csv("https://github.com/sivacivil12345/Power-bi-dashboard/raw/refs/heads/main/State-Level_Transportation_Public_Finance_Statistics__TPFS_.csv")

df.head(10)
# Out:
#   cash_flow own_supporting user_other      trust_fund exp_type  \
# 0   Revenue     Supporting      Other  Non-Trust Fund        -
# 1   Revenue     Supporting      Other  Non-Trust Fund        -
# 2   Revenue     Supporting      Other  Non-Trust Fund        -
# 3   Revenue     Supporting      Other  Non-Trust Fund        -
# 4   Revenue     Supporting      Other  Non-Trust Fund        -
# 5   Revenue     Supporting      Other  Non-Trust Fund        -
# 6   Revenue     Supporting      Other  Non-Trust Fund        -
# 7   Revenue     Supporting      Other  Non-Trust Fund        -
# 8   Revenue     Supporting      Other  Non-Trust Fund        -
# 9   Revenue     Supporting      Other  Non-Trust Fund        -
#
#          gov_level          description     state state_code  year  ...  \
# 0  State and Local  State general funds   Alabama         AL  2020  ...
# 1  State and Local  State general funds   Alabama         AL  2021  ...
# 2  State and Local  State general funds   Alabama         AL  2022  ...
# 3  State and Local  State general funds    Alaska         AK  2020  ...
# 4  State and Local  State general funds    Alaska         AK  2021  ...
# 5  State and Local  State general funds    Alaska         AK  2022  ...
# 6  State and Local  State general funds   Arizona         AZ  2020  ...
# 7  State and Local  State general funds   Arizona         AZ  2021  ...
# 8  State and Local  State general funds   Arizona         AZ  2022  ...
# 9  State and Local  State general funds  Arkansas         AR  2020  ...
#
#   deflator       chained gov_level_sort_order  mode_sort_order  \
# 0  106.515  6.688354e+07                    1                0
# 1  116.734  4.848459e+07                    1                0
# 2  128.921  0.000000e+00                    1                0
# 3  106.515  1.085068e+08                    1                0
# 4  116.734  1.636293e+08                    1                0
# 5  128.921  1.186448e+08                    1                0
# 6  106.515  2.983617e+06                    1                0
# 7  116.734  3.222711e+06                    1                0
# 8  128.921  6.334887e+06                    1                0
# 9  106.515  3.980660e+07                    1                0
#
#    user_other_grp  chained_year  state_code_sort_order population  \
# 0           Other          2017                      2    5025369
# 1           Other          2017                      2    5049196
# 2           Other          2017                      2    5076181
# 3           Other          2017                      1     733395
# 4           Other          2017                      1     734420
# 5           Other          2017                      1     734442
# 6           Other          2017                      5    7158110
# 7           Other          2017                      5    7274078
# 8           Other          2017                      5    7377566
# 9           Other          2017                      3    3011553
#
#    value_per_pop  chained_per_pop
# 0      14.176272        13.309179
# 1      11.209309         9.602437
# 2       0.000000         0.000000
# 3     157.590384       147.951354
# 4     260.084148       222.800682
# 5     208.264233       161.544072
# 6       0.443972         0.416816
# 7       0.517179         0.443041
# 8       1.107005         0.858669
# 9      14.079115        13.217964
#
# [10 rows x 23 columns]

# %% [markdown]
# # **Pandas Attributes:**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15636 entries, 0 to 15635
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   cash_flow              15636 non-null  object
#  1   own_supporting         15636 non-null  object
#  2   user_other             15636 non-null  object
#  3   trust_fund             15636 non-null  object
#  4   exp_type               15636 non-null  object
#  5   gov_level              15636 non-null  object
#  6   description            15636 non-null  object
#  7   state                  15636 non-null  object
#  8   state_code             15636 non-null  object
#  9   year                   15636 non-null  int64
#  10  estimate_actual        15636 non-null  object
#  11  value                  15636 non-null  float64
#  12  mode                   15636 non-null  object
#  13  deflator               11074 non-null  float64
#  14  chained                11074 non-null  float64
#  15  gov_level_sort_order   15636 non-null  int64
#  16  mode_sort_order        15636 non-null  int64
#  17  user_other_grp         15636 non-null  object
#  18  chained_year           15636 non-null  int64
#  19  state_code_sort_order  15636 non-null  int64
#  20  population             15636 non-null  int64
#  21  value_per_pop          15636 non-null  float64
#  22  chained_per_pop        11074 non-null  float64
# dtypes: float64(5), int64(6), object(12)
# memory usage: 2.7+ MB

# %%
df.shape
# Out:
# (15636, 23)

# %%
df.nunique()
# Out:
# cash_flow                    2
# own_supporting               4
# user_other                   5
# trust_fund                   2
# exp_type                     4
# gov_level                    2
# description                 59
# state                       56
# state_code                  56
# year                         4
# estimate_actual              1
# value                    10147
# mode                         4
# deflator                     4
# chained                   7371
# gov_level_sort_order         2
# mode_sort_order              4
# user_other_grp               4
# chained_year                 1
# state_code_sort_order       56
# population                 224
# value_per_pop            10241
# chained_per_pop           7382
# dtype: int64

# %%
df.isnull().sum()
# Out:
# cash_flow                   0
# own_supporting              0
# user_other                  0
# trust_fund                  0
# exp_type                    0
# gov_level                   0
# description                 0
# state                       0
# state_code                  0
# year                        0
# estimate_actual             0
# value                       0
# mode                        0
# deflator                 4562
# chained                  4562
# gov_level_sort_order        0
# mode_sort_order             0
# user_other_grp              0
# chained_year                0
# state_code_sort_order       0
# population                  0
# value_per_pop               0
# chained_per_pop          4562
# dtype: int64

# %%
df.isnull().mean()*100
# Out:
# cash_flow                 0.00000
# own_supporting            0.00000
# user_other                0.00000
# trust_fund                0.00000
# exp_type                  0.00000
# gov_level                 0.00000
# description               0.00000
# state                     0.00000
# state_code                0.00000
# year                      0.00000
# estimate_actual           0.00000
# value                     0.00000
# mode                      0.00000
# deflator                 29.17626
# chained                  29.17626
# gov_level_sort_order      0.00000
# mode_sort_order           0.00000
# user_other_grp            0.00000
# chained_year              0.00000
# state_code_sort_order     0.00000
# population                0.00000
# value_per_pop             0.00000
# chained_per_pop          29.17626
# dtype: float64

# %%
df.describe()
# Out:
#                year         value      deflator       chained  \
# count  15636.000000  1.563600e+04  11074.000000  1.107400e+04
# mean    2021.322333  6.946174e+08    119.348362  1.671063e+08
# std        1.048838  2.308908e+09      9.690714  5.485874e+08
# min     2020.000000 -2.553460e+08    106.515000 -2.187418e+08
# 25%     2020.000000  5.252000e+03    106.515000  0.000000e+00
# 50%     2021.000000  3.894328e+07    116.734000  5.333808e+06
# 75%     2022.000000  4.139948e+08    128.921000  9.300031e+07
# max     2023.000000  4.261266e+10    130.744000  1.248552e+10
#
#        gov_level_sort_order  mode_sort_order  chained_year  \
# count          15636.000000     15636.000000       15636.0
# mean            2918.042466       957.997889        2017.0
# std             4544.972490      2941.927882           0.0
# min                1.000000         0.000000        2017.0
# 25%                1.000000         0.000000        2017.0
# 50%                1.000000         1.000000        2017.0
# 75%             9999.000000         1.000000        2017.0
# max             9999.000000      9999.000000        2017.0
#
#        state_code_sort_order    population  value_per_pop  chained_per_pop
# count           15636.000000  1.563600e+04   15636.000000     11074.000000
# mean               28.572525  6.181265e+06     110.473350        26.578087
# std                16.108909  7.273978e+06     241.116961        62.636602
# min                 1.000000  4.462000e+04    -143.001471      -122.501988
# 25%                15.000000  1.402199e+06       0.001093         0.000000
# 50%                29.000000  4.063882e+06      13.581111         1.555833
# 75%                42.000000  7.274078e+06      86.147346        23.714071
# max                56.000000  3.955567e+07    2717.567213       845.057648

# %% [markdown]
# ## Stage 2 – Data Cleaning and Pre-processing
#
# - Handle missing values (impute or drop)
#
# - Handle duplicates
# - column name rename or dropping unwanted columns if required
#
# - Treat outliers if required
#
# - Check skewness and apply transformations
#
# - Convert data types if needed
#
# - Feature transformations (date parts, derived fields if required for analysis)

# %%
print('\nduplicated values')
print(df.duplicated().sum())
# Out:
# duplicated values
# 0

# %%
# Drop duplicate values

df.drop_duplicates()
# Out:
#       cash_flow own_supporting  user_other      trust_fund exp_type  \
# 0       Revenue     Supporting       Other  Non-Trust Fund        -
# 1       Revenue     Supporting       Other  Non-Trust Fund        -
# 2       Revenue     Supporting       Other  Non-Trust Fund        -
# 3       Revenue     Supporting       Other  Non-Trust Fund        -
# 4       Revenue     Supporting       Other  Non-Trust Fund        -
# ...         ...            ...         ...             ...      ...
# 15631   Revenue          Total       Other           Total    Total
# 15632   Revenue          Total  User-Based           Total    Total
# 15633   Revenue          Total  User-Based           Total    Total
# 15634   Revenue          Total  User-Based           Total    Total
# 15635   Revenue          Total  User-Based           Total    Total
#
#              gov_level          description           state state_code  year  \
# 0      State and Local  State general funds         Alabama         AL  2020
# 1      State and Local  State general funds         Alabama         AL  2021
# 2      State and Local  State general funds         Alabama         AL  2022
# 3      State and Local  State general funds          Alaska         AK  2020
# 4      State and Local  State general funds          Alaska         AK  2021
# ...                ...                  ...             ...        ...   ...
# 15631            Total                    -  Virgin Islands         VI  2023
# 15632            Total                    -  Virgin Islands         VI  2020
# 15633            Total                    -  Virgin Islands         VI  2021
# 15634            Total                    -  Virgin Islands         VI  2022
# 15635            Total                    -  Virgin Islands         VI  2023
#
#        ... deflator       chained gov_level_sort_order  mode_sort_order  \
# 0      ...  106.515  6.688354e+07                    1                0
# 1      ...  116.734  4.848459e+07                    1                0
# 2      ...  128.921  0.000000e+00                    1                0
# 3      ...  106.515  1.085068e+08                    1                0
# 4      ...  116.734  1.636293e+08                    1                0
# ...    ...      ...           ...                  ...              ...
# 15631  ...      NaN           NaN                 9999             9999
# 15632  ...      NaN           NaN                 9999             9999
# 15633  ...      NaN           NaN                 9999             9999
# 15634  ...      NaN           NaN                 9999             9999
# 15635  ...      NaN           NaN                 9999             9999
#
#        user_other_grp  chained_year  state_code_sort_order population  \
# 0               Other          2017                      2    5025369
# 1               Other          2017                      2    5049196
# 2               Other          2017                      2    5076181
# 3               Other          2017                      1     733395
# 4               Other          2017                      1     734420
# ...               ...           ...                    ...        ...
# 15631           Other          2017                     51     104917
# 15632      User-Based          2017                     51      87146
# 15633      User-Based          2017                     51     105870
# 15634      User-Based          2017                     51     105413
# 15635      User-Based          2017                     51     104917
#
#        value_per_pop  chained_per_pop
# 0          14.176272        13.309179
# 1          11.209309         9.602437
# 2           0.000000         0.000000
# 3         157.590384       147.951354
# 4         260.084148       222.800682
# ...              ...              ...
# 15631      13.738803              NaN
# 15632     288.780690              NaN
# 15633     333.238878              NaN
# 15634     360.431123              NaN
# 15635     329.807696              NaN
#
# [15636 rows x 23 columns]

# %%
# Drop unwanted columns

df.drop(['exp_type','state_code','gov_level','mode_sort_order','state_code_sort_order','gov_level_sort_order','user_other','estimate_actual','user_other_grp','chained_year'],axis=1,inplace=True)

# %%
df=df.columns.str.title()

# %%
df
# Out:
# Index(['Cash_Flow', 'Own_Supporting', 'Trust_Fund', 'Description', 'State',
#        'Year', 'Value', 'Mode', 'Deflator', 'Chained', 'Population',
#        'Value_Per_Pop', 'Chained_Per_Pop'],
#       dtype='object')

# %%
df['deflator'].fillna(df['deflator'].mean(),inplace=True)
df['chained'].fillna(df['chained'].mean(),inplace=True)
df['chained_per_pop'].fillna(df['chained_per_pop'].mean(),inplace=True)
# Out:
# /tmp/ipykernel_697/4245752686.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['deflator'].fillna(df['deflator'].mean(),inplace=True)
# /tmp/ipykernel_697/4245752686.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['chained'].fillna(df['chained'].mean(),inplace=True)
# /tmp/ipykernel_697/4245752686.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['chained_per_pop'].fillna(df['chained_per_pop'].mean(),inplace=True)

# %%
# Rename the columns name

df.rename(columns={'trust_fund':'fund_type','own_supporting':'supporting_type'},inplace=True)

# %%
df
# Out:
#       cash_flow supporting_type       fund_type          description  \
# 0       Revenue      Supporting  Non-Trust Fund  State general funds
# 1       Revenue      Supporting  Non-Trust Fund  State general funds
# 2       Revenue      Supporting  Non-Trust Fund  State general funds
# 3       Revenue      Supporting  Non-Trust Fund  State general funds
# 4       Revenue      Supporting  Non-Trust Fund  State general funds
# ...         ...             ...             ...                  ...
# 15631   Revenue           Total           Total                    -
# 15632   Revenue           Total           Total                    -
# 15633   Revenue           Total           Total                    -
# 15634   Revenue           Total           Total                    -
# 15635   Revenue           Total           Total                    -
#
#                 state  year        value      mode    deflator       chained  \
# 0             Alabama  2020   71241000.0  Highways  106.515000  6.688354e+07
# 1             Alabama  2021   56598000.0  Highways  116.734000  4.848459e+07
# 2             Alabama  2022          0.0  Highways  128.921000  0.000000e+00
# 3              Alaska  2020  115576000.0  Highways  106.515000  1.085068e+08
# 4              Alaska  2021  191011000.0  Highways  116.734000  1.636293e+08
# ...               ...   ...          ...       ...         ...           ...
# 15631  Virgin Islands  2023    1441434.0     Total  119.348362  1.671063e+08
# 15632  Virgin Islands  2020   25166082.0     Total  119.348362  1.671063e+08
# 15633  Virgin Islands  2021   35280000.0     Total  119.348362  1.671063e+08
# 15634  Virgin Islands  2022   37994126.0     Total  119.348362  1.671063e+08
# 15635  Virgin Islands  2023   34602434.0     Total  119.348362  1.671063e+08
#
#        population  value_per_pop  chained_per_pop
# 0         5025369      14.176272        13.309179
# 1         5049196      11.209309         9.602437
# 2         5076181       0.000000         0.000000
# 3          733395     157.590384       147.951354
# 4          734420     260.084148       222.800682
# ...           ...            ...              ...
# 15631      104917      13.738803        26.578087
# 15632       87146     288.780690        26.578087
# 15633      105870     333.238878        26.578087
# 15634      105413     360.431123        26.578087
# 15635      104917     329.807696        26.578087
#
# [15636 rows x 13 columns]

# %%
# Replace

df['supporting_type']=df['supporting_type'].replace({'Total':'Other Supporting'})
df['fund_type']=df['fund_type'].replace({'total':'trust fund'})
df['description']=df['description'].replace({'-':'other'})

# %%
df
# Out:
#       cash_flow   supporting_type       fund_type          description  \
# 0       Revenue        Supporting  Non-Trust Fund  State general funds
# 1       Revenue        Supporting  Non-Trust Fund  State general funds
# 2       Revenue        Supporting  Non-Trust Fund  State general funds
# 3       Revenue        Supporting  Non-Trust Fund  State general funds
# 4       Revenue        Supporting  Non-Trust Fund  State general funds
# ...         ...               ...             ...                  ...
# 15631   Revenue  Other Supporting           Total                other
# 15632   Revenue  Other Supporting           Total                other
# 15633   Revenue  Other Supporting           Total                other
# 15634   Revenue  Other Supporting           Total                other
# 15635   Revenue  Other Supporting           Total                other
#
#                 state  year        value      mode    deflator       chained  \
# 0             Alabama  2020   71241000.0  Highways  106.515000  6.688354e+07
# 1             Alabama  2021   56598000.0  Highways  116.734000  4.848459e+07
# 2             Alabama  2022          0.0  Highways  128.921000  0.000000e+00
# 3              Alaska  2020  115576000.0  Highways  106.515000  1.085068e+08
# 4              Alaska  2021  191011000.0  Highways  116.734000  1.636293e+08
# ...               ...   ...          ...       ...         ...           ...
# 15631  Virgin Islands  2023    1441434.0     Total  119.348362  1.671063e+08
# 15632  Virgin Islands  2020   25166082.0     Total  119.348362  1.671063e+08
# 15633  Virgin Islands  2021   35280000.0     Total  119.348362  1.671063e+08
# 15634  Virgin Islands  2022   37994126.0     Total  119.348362  1.671063e+08
# 15635  Virgin Islands  2023   34602434.0     Total  119.348362  1.671063e+08
#
#        population  value_per_pop  chained_per_pop
# 0         5025369      14.176272        13.309179
# 1         5049196      11.209309         9.602437
# 2         5076181       0.000000         0.000000
# 3          733395     157.590384       147.951354
# 4          734420     260.084148       222.800682
# ...           ...            ...              ...
# 15631      104917      13.738803        26.578087
# 15632       87146     288.780690        26.578087
# 15633      105870     333.238878        26.578087
# 15634      105413     360.431123        26.578087
# 15635      104917     329.807696        26.578087
#
# [15636 rows x 13 columns]

# %%
df['value_crore']=(df['value']/10000000).round(2)
df['population_crore']=(df['population']/10000000).round(5)

# %%
df
# Out:
#       cash_flow   supporting_type       fund_type          description  \
# 0       Revenue        Supporting  Non-Trust Fund  State general funds
# 1       Revenue        Supporting  Non-Trust Fund  State general funds
# 2       Revenue        Supporting  Non-Trust Fund  State general funds
# 3       Revenue        Supporting  Non-Trust Fund  State general funds
# 4       Revenue        Supporting  Non-Trust Fund  State general funds
# ...         ...               ...             ...                  ...
# 15631   Revenue  Other Supporting           Total                other
# 15632   Revenue  Other Supporting           Total                other
# 15633   Revenue  Other Supporting           Total                other
# 15634   Revenue  Other Supporting           Total                other
# 15635   Revenue  Other Supporting           Total                other
#
#                 state  year        value      mode    deflator       chained  \
# 0             Alabama  2020   71241000.0  Highways  106.515000  6.688354e+07
# 1             Alabama  2021   56598000.0  Highways  116.734000  4.848459e+07
# 2             Alabama  2022          0.0  Highways  128.921000  0.000000e+00
# 3              Alaska  2020  115576000.0  Highways  106.515000  1.085068e+08
# 4              Alaska  2021  191011000.0  Highways  116.734000  1.636293e+08
# ...               ...   ...          ...       ...         ...           ...
# 15631  Virgin Islands  2023    1441434.0     Total  119.348362  1.671063e+08
# 15632  Virgin Islands  2020   25166082.0     Total  119.348362  1.671063e+08
# 15633  Virgin Islands  2021   35280000.0     Total  119.348362  1.671063e+08
# 15634  Virgin Islands  2022   37994126.0     Total  119.348362  1.671063e+08
# 15635  Virgin Islands  2023   34602434.0     Total  119.348362  1.671063e+08
#
#        population  value_per_pop  chained_per_pop  value_crore  \
# 0         5025369      14.176272        13.309179         7.12
# 1         5049196      11.209309         9.602437         5.66
# 2         5076181       0.000000         0.000000         0.00
# 3          733395     157.590384       147.951354        11.56
# 4          734420     260.084148       222.800682        19.10
# ...           ...            ...              ...          ...
# 15631      104917      13.738803        26.578087         0.14
# 15632       87146     288.780690        26.578087         2.52
# 15633      105870     333.238878        26.578087         3.53
# 15634      105413     360.431123        26.578087         3.80
# 15635      104917     329.807696        26.578087         3.46
#
#        population_crore
# 0               0.50254
# 1               0.50492
# 2               0.50762
# 3               0.07334
# 4               0.07344
# ...                 ...
# 15631           0.01049
# 15632           0.00871
# 15633           0.01059
# 15634           0.01054
# 15635           0.01049
#
# [15636 rows x 15 columns]

# %%
df.groupby('cash_flow')['value_crore'].sum()
# Out:
# cash_flow
# Expenditure    605833.34
# Revenue        480270.17
# Name: value_crore, dtype: float64

# %%
df.groupby('mode')['value_crore'].sum()
# Out:
# mode
# Air          83184.09
# Highways    422677.31
# Total       406223.85
# Transit     174018.26
# Name: value_crore, dtype: float64

# %%
df.groupby('state')['value_crore'].sum()
# Out:
# state
# Alabama                       7274.00
# Alaska                        4815.73
# American Samoa                  35.51
# Arizona                      14928.36
# Arkansas                      7721.24
# California                  136308.02
# Colorado                     22496.81
# Connecticut                  10255.20
# Delaware                      5571.93
# District of Columbia          4169.02
# Florida                      58713.98
# Georgia                      20909.39
# Guam                           252.78
# Hawaii                        6975.06
# Idaho                         4083.85
# Illinois                     50315.84
# Indiana                      14248.01
# Iowa                          9409.70
# Kansas                        7658.54
# Kentucky                      9676.82
# Louisiana                     6723.42
# Maine                         4703.98
# Maryland                     24809.14
# Massachusetts                30707.37
# Michigan                     23495.16
# Minnesota                    23026.41
# Mississippi                   4320.39
# Missouri                     12796.62
# Montana                       3737.50
# Nebraska                      5671.92
# Nevada                        9867.60
# New Hampshire                 3193.24
# New Jersey                   37526.58
# New Mexico                    5146.41
# New York                    131650.60
# North Carolina               23288.34
# North Dakota                  2944.59
# Northern Mariana Islands        53.30
# Ohio                         24173.95
# Oklahoma                     10936.27
# Oregon                       13709.14
# Pennsylvania                 57867.19
# Puerto Rico                   1447.55
# Rhode Island                  2464.15
# South Carolina               11403.47
# South Dakota                  3424.21
# Tennessee                    10497.42
# Texas                        87911.68
# Utah                         12452.61
# Vermont                       2306.91
# Virgin Islands                 162.48
# Virginia                     32859.18
# Washington                   40364.85
# West Virginia                 5907.79
# Wisconsin                    15057.58
# Wyoming                       3674.72
# Name: value_crore, dtype: float64

# %%
df.groupby('state')['population_crore'].sum()
# Out:
# state
# Alabama                      145.75113
# Alaska                        21.15207
# American Samoa                 0.92235
# Arizona                      210.28788
# Arkansas                      87.41097
# California                  1130.90382
# Colorado                     167.82147
# Connecticut                  104.13432
# Delaware                      29.09097
# District of Columbia          16.73070
# Florida                      635.64219
# Georgia                      312.53517
# Guam                           3.26952
# Hawaii                        41.66217
# Idaho                         54.94437
# Illinois                     365.85837
# Indiana                      196.58115
# Iowa                          92.17719
# Kansas                        84.66948
# Kentucky                     130.09581
# Louisiana                    133.07121
# Maine                         39.77550
# Maryland                     178.25949
# Massachusetts                202.35411
# Michigan                     289.76526
# Minnesota                    164.77920
# Mississippi                   84.93264
# Missouri                     177.83217
# Montana                       31.92453
# Nebraska                      56.72502
# Nevada                        90.84618
# New Hampshire                 40.02129
# New Jersey                   267.83127
# New Mexico                    60.97068
# New York                     572.84028
# North Carolina               305.86986
# North Dakota                  22.48911
# Northern Mariana Islands       0.99840
# Ohio                         339.50007
# Oklahoma                     115.30773
# Oregon                       122.32674
# Pennsylvania                 374.50800
# Puerto Rico                   64.23747
# Rhode Island                  31.64751
# South Carolina               150.60915
# South Dakota                  25.94484
# Tennessee                    201.78297
# Texas                        857.82609
# Utah                          96.51303
# Vermont                       18.62019
# Virgin Islands                 1.99389
# Virginia                     249.69312
# Washington                   223.64640
# West Virginia                 51.32979
# Wisconsin                    169.89318
# Wyoming                       16.71399
# Name: population_crore, dtype: float64

# %% [markdown]
# KEY FINDING:
#
# 1.Analysing the cash flow, Expenditure value is greater than revenue value
#
# 2.Highway transportation receives the highest funding and spending.
# Air transportation represents the smallest share of transportation finance.
#
# 3.California and New York dominate transportation spending and revenue.
# Larger population states generally have higher transportation budgets.

# %%
# for the find the outliers

import seaborn as sns
import matplotlib.pyplot as plt

numerical_col=df.select_dtypes(include=['int64','float64']).columns

for col in numerical_col:
  plt.figure(figsize=(7,4))
  sns.boxplot(x=df[col])
  plt.title(f'boxplot of{col}')
  plt.show()

# %%
# for finding outliers (in numbers)

for col in numerical_col:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    outliers = df[(df[col] < lower) | (df[col] > upper)]

    print(f"{col}: {len(outliers)} outliers")
# Out:
# year: 0 outliers
# value: 2218 outliers
# deflator: 0 outliers
# chained: 1157 outliers
# population: 1152 outliers
# value_per_pop: 2345 outliers
# chained_per_pop: 1328 outliers
# value_crore: 2218 outliers
# population_crore: 1152 outliers

# %%
for col in numerical_col:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

df[(df[col]>lower)|(df[col]<upper)]
# Out:
#       cash_flow   supporting_type       fund_type          description  \
# 0       Revenue        Supporting  Non-Trust Fund  State general funds
# 1       Revenue        Supporting  Non-Trust Fund  State general funds
# 2       Revenue        Supporting  Non-Trust Fund  State general funds
# 3       Revenue        Supporting  Non-Trust Fund  State general funds
# 4       Revenue        Supporting  Non-Trust Fund  State general funds
# ...         ...               ...             ...                  ...
# 15631   Revenue  Other Supporting           Total                other
# 15632   Revenue  Other Supporting           Total                other
# 15633   Revenue  Other Supporting           Total                other
# 15634   Revenue  Other Supporting           Total                other
# 15635   Revenue  Other Supporting           Total                other
#
#                 state  year        value      mode    deflator       chained  \
# 0             Alabama  2020   71241000.0  Highways  106.515000  6.688354e+07
# 1             Alabama  2021   56598000.0  Highways  116.734000  4.848459e+07
# 2             Alabama  2022          0.0  Highways  128.921000  0.000000e+00
# 3              Alaska  2020  115576000.0  Highways  106.515000  1.085068e+08
# 4              Alaska  2021  191011000.0  Highways  116.734000  1.636293e+08
# ...               ...   ...          ...       ...         ...           ...
# 15631  Virgin Islands  2023    1441434.0     Total  119.348362  1.671063e+08
# 15632  Virgin Islands  2020   25166082.0     Total  119.348362  1.671063e+08
# 15633  Virgin Islands  2021   35280000.0     Total  119.348362  1.671063e+08
# 15634  Virgin Islands  2022   37994126.0     Total  119.348362  1.671063e+08
# 15635  Virgin Islands  2023   34602434.0     Total  119.348362  1.671063e+08
#
#        population  value_per_pop  chained_per_pop  value_crore  \
# 0         5025369      14.176272        13.309179         7.12
# 1         5049196      11.209309         9.602437         5.66
# 2         5076181       0.000000         0.000000         0.00
# 3          733395     157.590384       147.951354        11.56
# 4          734420     260.084148       222.800682        19.10
# ...           ...            ...              ...          ...
# 15631      104917      13.738803        26.578087         0.14
# 15632       87146     288.780690        26.578087         2.52
# 15633      105870     333.238878        26.578087         3.53
# 15634      105413     360.431123        26.578087         3.80
# 15635      104917     329.807696        26.578087         3.46
#
#        population_crore
# 0               0.50254
# 1               0.50492
# 2               0.50762
# 3               0.07334
# 4               0.07344
# ...                 ...
# 15631           0.01049
# 15632           0.00871
# 15633           0.01059
# 15634           0.01054
# 15635           0.01049
#
# [15636 rows x 15 columns]

# %%
df
# Out:
#       cash_flow   supporting_type       fund_type          description  \
# 0       Revenue        Supporting  Non-Trust Fund  State general funds
# 1       Revenue        Supporting  Non-Trust Fund  State general funds
# 2       Revenue        Supporting  Non-Trust Fund  State general funds
# 3       Revenue        Supporting  Non-Trust Fund  State general funds
# 4       Revenue        Supporting  Non-Trust Fund  State general funds
# ...         ...               ...             ...                  ...
# 15631   Revenue  Other Supporting           Total                other
# 15632   Revenue  Other Supporting           Total                other
# 15633   Revenue  Other Supporting           Total                other
# 15634   Revenue  Other Supporting           Total                other
# 15635   Revenue  Other Supporting           Total                other
#
#                 state  year        value      mode    deflator       chained  \
# 0             Alabama  2020   71241000.0  Highways  106.515000  6.688354e+07
# 1             Alabama  2021   56598000.0  Highways  116.734000  4.848459e+07
# 2             Alabama  2022          0.0  Highways  128.921000  0.000000e+00
# 3              Alaska  2020  115576000.0  Highways  106.515000  1.085068e+08
# 4              Alaska  2021  191011000.0  Highways  116.734000  1.636293e+08
# ...               ...   ...          ...       ...         ...           ...
# 15631  Virgin Islands  2023    1441434.0     Total  119.348362  1.671063e+08
# 15632  Virgin Islands  2020   25166082.0     Total  119.348362  1.671063e+08
# 15633  Virgin Islands  2021   35280000.0     Total  119.348362  1.671063e+08
# 15634  Virgin Islands  2022   37994126.0     Total  119.348362  1.671063e+08
# 15635  Virgin Islands  2023   34602434.0     Total  119.348362  1.671063e+08
#
#        population  value_per_pop  chained_per_pop  value_crore  \
# 0         5025369      14.176272        13.309179         7.12
# 1         5049196      11.209309         9.602437         5.66
# 2         5076181       0.000000         0.000000         0.00
# 3          733395     157.590384       147.951354        11.56
# 4          734420     260.084148       222.800682        19.10
# ...           ...            ...              ...          ...
# 15631      104917      13.738803        26.578087         0.14
# 15632       87146     288.780690        26.578087         2.52
# 15633      105870     333.238878        26.578087         3.53
# 15634      105413     360.431123        26.578087         3.80
# 15635      104917     329.807696        26.578087         3.46
#
#        population_crore
# 0               0.50254
# 1               0.50492
# 2               0.50762
# 3               0.07334
# 4               0.07344
# ...                 ...
# 15631           0.01049
# 15632           0.00871
# 15633           0.01059
# 15634           0.01054
# 15635           0.01049
#
# [15636 rows x 15 columns]

# %% [markdown]
# ## Stage 3 – EDA and Visualizations
#
# Univariate Analysis → distribution of single variables (countplot, histogram, boxplot)
#
# Bivariate Analysis → relation between two variables (scatterplot, barplot, correlation heatmap)
#
# Multivariate Analysis → relation among 3+ variables (pairplot, grouped analysis, pivot tables, advanced plots)
#
# Interpretation MUST with every visualization
#
# Focus on business story not just charts
#
# Each chart must be in seperate cells.

# %% [markdown]
# # **Note For Kind of Analysis to be done**
#
# **Type of Analysis**
#
# * Descriptive Analysis (summarizing the dataset)
#
# * Diagnostic Analysis (finding reasons behind patterns)
#
# * Predictive Analysis (optional if forecasting required using basic stats)
#
# * Prescriptive Analysis (recommendations for business decisions)

# %% [markdown]
# ### Analysis about the sales by region

# %%
# your chart here
# If you want more cells, you can add or less cells you can remove, but dont change the structure.

# %% [markdown]
# ### **Insights**
#
# * point by point insight should be recorded

# %% [markdown]
# ## Interpretation of your above chart
#
# Explain the Chart.
#
# What is it saying?
#
# What features you used?
#
# From this what you are showing us?

# %%
# your code here
# If you want more cells, you can add or less cells you can remove, but dont change the structure.

# %%
a=10
print("hai")
# Out:
#   File "/tmp/ipykernel_607/2666902648.py", line 2
#     print("hai")
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# ## Interpretation of your above chart
#
# Explain the Chart.
#
# What is it saying?
#
# What features you used?
#
# From this what you are showing us?

# %%
# your code here
# If you want more cells, you can add or less cells you can remove, but dont change the structure.

# %% [markdown]
# ## Interpretation of your above chart
#
# Explain the Chart.
#
# What is it saying?
#
# What features you used?
#
# From this what you are showing us?

# %%
# your code here
# If you want more cells, you can add or less cells you can remove, but dont change the structure.

# %% [markdown]
# ## Interpretation of your above chart
#
# Explain the Chart.
#
# What is it saying?
#
# What features you used?
#
# From this what you are showing us?

# %%
# your code here
# If you want more cells, you can add or less cells you can remove, but dont change the structure.

# %% [markdown]
# ## Interpretation of your above chart
#
# Explain the Chart.
#
# What is it saying?
#
# What features/columns you used?
#
# From this what you are showing us?

# %% [markdown]
# ## **Steps to Download your cleaned data for dashboard creation using Power BI**

# %%
import pandas as pd
df=pd.read_csv("https://raw.githubusercontent.com/geethag-sys/Health-care-analysis3/refs/heads/main/insurance.csv")
df.to_csv("insurance.csv")

# %% [markdown]
# ## Stage 4 – Documentation, Insights and Presentation
#
# Show a dashboard aligning all the charts in powerbi by connecting python in PowerBI
#
# Summarize findings in plain English (what do the patterns mean)
#
# Highlight 3–5 key insights (trends, anomalies, correlations)
#
# Provide recommendations for business or decision-making
#
# Explain the FINAL STORY WITH THE DASHBOARD/report
#
# Create a PDF pasting your DASHBOARD, explaining all the above mentioned concepts and submit it

# %% [markdown]
# ![dash-img.png](data:image/png;base64,...)

# %%
# your stage 4 pdf Link

'''
step1 --> Create a docs that should have all the above mentioned
step2 --> Save it as "Stage4_doc"
Step3 --> Download it as PDF
step4 --> Upload the pdf in your drive
step5 --> Right click on your pdf in drive
step6 --> click share and change access into anyone with the link (Viewer)
step7 --> click copy link and paste it here...
You are done.
'''

# %% [markdown]
# ## **Final Overall Insights:**
# * insights from the final dashboard observation on the basics of 4 types of analysis

# %% [markdown]
# # Future Enhancement
#
# Use a larger or more recent dataset for deeper insights
#
# Automate parts of the analysis with scripts or dashboards
#
# Add advanced visualizations and interactive dashboards in Power BI or Tableau
#
# Extend the analysis to predictive modeling for forecasting if needed

# %% [markdown]
# # Conclusion
#
# From the analysis, we identified meaningful relationships and patterns in the dataset. The visualizations and insights highlight the main factors influencing the outcomes and provide a strong foundation for business decisions.
